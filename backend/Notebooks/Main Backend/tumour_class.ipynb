# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive"
import tensorflow as tf

# Model Load karo
model = tf.keras.models.load_model('/content/drive/MyDrive/mymobilenet_final_model_for_tumour.keras')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'Colab Notebooks'		     mymobilenet_final_model_for_tumour.keras
# 'Dog Vision'			    'My Zaalima'
#  faster_whisper_module.py	     New_in_NLP.ipynb
#  Insurance_regression_via_TF.ipynb   Regression_with_neural_network.ipynb
#  jhu				     tumour_class.ipynb
# 'llama_3_8b_med_tune (3).ipynb'      Tumour_model.py
#  LlamaMedTuner.py		     Untitled0.ipynb
# 'Master (1).ipynb'

# %%
import numpy as np
import cv2
from google.colab import files
from tensorflow.keras.preprocessing import image

# Image Upload
uploaded = files.upload()

for filename in uploaded.keys():
    img_path = filename

# Image ko Read karo aur Resize karo
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalize

# Prediction lo
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions)

# Class Labels dikhane ke liye
class_labels = ['G', 'R', 'U']
print(f"The image contains the tumour : {class_labels[predicted_class]}")
# Out:
#      <input type="file" id="files-7548aa6c-d9ce-43eb-960c-2aa24b73d6df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7548aa6c-d9ce-43eb-960c-2aa24b73d6df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
